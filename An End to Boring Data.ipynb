# %% [markdown]
# # Learning Pandas and Matplotlib

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read NYC Restaurant CSV

# %%
rests = pd.read_csv("NYC Restaurants.csv")

# %%
mRests = rests[rests['BORO']=="MANHATTAN"] ## Look at only Manhattan Data

# %%
list(mRests.columns.values)
# Out:
# ['CAMIS',
#  'DBA',
#  'BORO',
#  'BUILDING',
#  'STREET',
#  'ZIPCODE',
#  'PHONE',
#  'CUISINE DESCRIPTION',
#  'INSPECTION DATE',
#  'ACTION',
#  'VIOLATION CODE',
#  'VIOLATION DESCRIPTION',
#  'CRITICAL FLAG',
#  'SCORE',
#  'GRADE',
#  'GRADE DATE',
#  'RECORD DATE',
#  'INSPECTION TYPE']

# %%
mRests = mRests[mRests['GRADE']!="Not Yet Graded"] ## Remove stores that have not been graded yet

# %%
mRests = mRests[pd.notnull(mRests["GRADE"])] ## Remove Stores that have no grade

# %%
mRests=mRests[pd.notnull(mRests["SCORE"])] ## Remove stores with no score

# %%
mRests["SCORE"].describe()
# Out:
# count    84381.000000
# mean        13.120051
# std          8.340741
# min         -1.000000
# 25%          9.000000
# 50%         11.000000
# 75%         13.000000
# max        131.000000
# Name: SCORE, dtype: float64

# %%
mRests["GRADE"] = mRests["GRADE"].astype("category",categories = ["A","B","C","P","Z"], ordered = True) ## redefine score levels

# %%
mRests = mRests.reset_index(drop=True)
mRests.head()
# Out:
#       CAMIS                     DBA       BORO BUILDING               STREET  \
# 0  41701548   TWO-BITS RETRO ARCADE  MANHATTAN      153         ESSEX STREET
# 1  41058228         CHA-AN TEAHOUSE  MANHATTAN      230     EAST    9 STREET
# 2  40424906      MANNA HOUSE BAKERY  MANHATTAN       87        EAST BROADWAY
# 3  41514752  FRANCOIS PAYARD BAKERY  MANHATTAN      116  WEST HOUSTON STREET
# 4  41288500            IL MELOGRANO  MANHATTAN      501       WEST 51 STREET
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0    10002  2124778161            American      04/03/2014
# 1    10003  2122288030            Japanese      12/22/2014
# 2    10002  2122676200              Bakery      04/27/2015
# 3    10012  2129950888              Bakery      11/12/2013
# 4    10019  2127579290             Italian      09/21/2015
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            06F
# 1  Violations were cited in the following area(s).            04H
# 2  Violations were cited in the following area(s).            06D
# 3  Violations were cited in the following area(s).            08A
# 4  Violations were cited in the following area(s).            02G
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0  Wiping cloths soiled or not stored in sanitizi...      Critical   23.0
# 1  Raw, cooked or prepared food is adulterated, c...      Critical    7.0
# 2  Food contact surface not properly washed, rins...      Critical   10.0
# 3  Facility not vermin proof. Harborage or condit...  Not Critical   10.0
# 4  Cold food item held above 41Âº F (smoked fish ...      Critical    9.0
#
#   GRADE  GRADE DATE RECORD DATE                        INSPECTION TYPE
# 0     B  04/03/2014  07/04/2016       Cycle Inspection / Re-inspection
# 1     A  12/22/2014  07/04/2016       Cycle Inspection / Re-inspection
# 2     A  04/27/2015  07/04/2016       Cycle Inspection / Re-inspection
# 3     A  11/12/2013  07/04/2016  Cycle Inspection / Initial Inspection
# 4     A  09/21/2015  07/04/2016       Cycle Inspection / Re-inspection

# %% [markdown]
# ## Plotting with Pandas and Matplotlib

# %% [markdown]
# ### Using Matplotlib

# %%
f, ax = plt.subplots() ## creates figure area with axes
# histogram our data with numpy
data = mRests['SCORE']

plt.hist(data)
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title("Frequency of Restaurant Scores")

plt.show()

# %% [markdown]
# ### Using Pandas

# %%
mRests["SCORE"].hist(bins=20)
plt.title("Frequency of Restaurant Score'")

# %%
mRests["GRADE"].value_counts().plot(kind = "pie")

# %%
mRests['CRITICAL FLAG'].value_counts().plot(kind='bar')

# %% [markdown]
# # Seaborn

# %%
## pip install seaborn
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
sns.stripplot(x="GRADE", y = "SCORE", data = mRests) #without jitter

# %%
sns.stripplot(x="GRADE", y = "SCORE", data = mRests, jitter = True)

# %%
sns.stripplot(x="GRADE", y = "SCORE", hue = "CRITICAL FLAG", data = mRests, jitter = True)

# %%
sns.boxplot(x="GRADE",y="SCORE", hue = "CRITICAL FLAG", data = mRests)

# %%
sns.barplot(x="GRADE", y = "SCORE", hue = "CRITICAL FLAG", data = mRests)

# %% [markdown]
# ## Convert Addresses to Lat/Long

# %%
import inflect
p = inflect.engine()
word_to_number_mapping = {}

for i in range(1, 200):
    word_form = p.number_to_words(i)  # 1 -> 'one'
    ordinal_word = p.ordinal(word_form)  # 'one' -> 'first'
    ordinal_number = p.ordinal(i)  # 1 -> '1st'
    word_to_number_mapping[ordinal_word] = ordinal_number  # 'first': '1st'

# %%
import re
for i in range(len(mRests)):

    street= mRests['STREET'][i].split()    
    for j in range(len(street)):
        if street[j].lower() in word_to_number_mapping:
            
            street[j]=  word_to_number_mapping[street[j].lower()]
#     streetFull = ' '.join(street)
    for j in range(len(street)):
        if re.findall(r'([0-9]+(st|rd|th|nd)+)', street[j].lower())==[]:
            if(filter(str.isdigit, street[j])!=''):
                val=int(filter(str.isdigit, street[j]))
                street[j]=street[j].replace(str(val), str(p.ordinal(val)))    
        streetFull = ' '.join(street)
        mRests.set_value(i,'STREET',streetFull)

# %%
mRests["STREET"]
# Out:
# 0                  ESSEX STREET
# 1               EAST 9th STREET
# 2                 EAST BROADWAY
# 3           WEST HOUSTON STREET
# 4              WEST 51st STREET
# 5                    LIBERTY ST
# 6                     MORTON ST
# 7                 HESTER STREET
# 8               EAST 6th STREET
# 9              WEST 40th STREET
# 10                 PEARL STREET
# 11                LEXINGTON AVE
# 12            UNION SQUARE EAST
# 13                   1st AVENUE
# 14                   1ST AVENUE
# 15             WEST 27th STREET
# 16                    W 58TH ST
# 17                THOMAS STREET
# 18                       BOWERY
# 19              COLUMBUS AVENUE
# 20                   5th AVENUE
# 21             EAST 23rd STREET
# 22                  MAIN STREET
# 23             WEST 48th STREET
# 24                   7th AVENUE
# 25              COMMERCE STREET
# 26                   8th AVENUE
# 27             WEST 33rd STREET
# 28                     PARK AVE
# 29            ROCKEFELLER PLAZA
#                   ...
# 84351                5th AVENUE
# 84352             LEXINGTON AVE
# 84353                  PARK AVE
# 84354                  BROADWAY
# 84355                7th AVENUE
# 84356                6th AVENUE
# 84357          WEST 43rd STREET
# 84358              LINCON PLAZA
# 84359    AVENUE OF THE AMERICAS
# 84360                  PARK ROW
# 84361         PARK AVENUE SOUTH
# 84362            MADISON AVENUE
# 84363          EAST 60TH STREET
# 84364                  BROADWAY
# 84365           EAST 7th STREET
# 84366          WEST 44th STREET
# 84367          WEST 17th STREET
# 84368                2nd AVENUE
# 84369          WEST 56th STREET
# 84370           CORNELIA STREET
# 84371          WEST 45th STREET
# 84372              LENOX AVENUE
# 84373            CARMINE STREET
# 84374    AVENUE OF THE AMERICAS
# 84375              LENOX AVENUE
# 84376          WEST 58th STREET
# 84377           CHRYSTIE STREET
# 84378                2nd AVENUE
# 84379          WEST 72nd STREET
# 84380          WEST 55th STREET
# Name: STREET, dtype: object

# %%
mRests["Address"]=mRests['BUILDING'].map(str)+ " " + mRests['STREET'].map(str)+ ", " + mRests['ZIPCODE'].map(str)

# %% [markdown]
# ### Sample data with same seed every time

# %%
# import random
np.random.seed(seed=10)
rows = np.random.choice(mRests.index.values, 100)
samp = mRests.ix[rows]
# samp = random.sample(mRests,90)
samp= samp.reset_index(drop=True)
samp
# Out:
#        CAMIS                                  DBA       BORO BUILDING  \
# 0   41632866                            CITY CAFE  MANHATTAN       35
# 1   50008977                               MOKBAR  MANHATTAN       75
# 2   41510644                            CURRY HUT  MANHATTAN      534
# 3   41706078                          AU BON PAIN  MANHATTAN      599
# 4   41520658                           V-NAM CAFE  MANHATTAN     1820
# 5   50017080                   TEN REN'S TEA TIME  MANHATTAN       73
# 6   41336336                             SOPHIE'S  MANHATTAN      507
# 7   40392430                          IPANEMA BAR  MANHATTAN      252
# 8   41602657                  WAT'S ON YOUR PLATE  MANHATTAN      513
# 9   41624304                    THE HUMMUS & PITA  MANHATTAN      585
# 10  41223396           THE BISTRO (HBO CAFETERIA)  MANHATTAN     1100
# 11  41529070             SPINELLI'S PIZZA/GYRO II  MANHATTAN      425
# 12  41393715                          YUM YUM TOO  MANHATTAN      662
# 13  41510644                            CURRY HUT  MANHATTAN      534
# 14  40559892                        QUALITY MEATS  MANHATTAN       57
# 15  41213444                           GOOGLE 5BB  MANHATTAN       76
# 16  41602357            JUST MADE SUSHI (DD MARU)  MANHATTAN      267
# 17  41302113                                GIANO  MANHATTAN      126
# 18  50003613                              DEE DAA  MANHATTAN      155
# 19  41310578                  EASTEND BAR & GRILL  MANHATTAN     1664
# 20  41066767                 DALTON'S BAR & GRILL  MANHATTAN      611
# 21  40765318                            CAFE DUKE  MANHATTAN      545
# 22  50006664               VILLARD MICHEL RICHARD  MANHATTAN      455
# 23  41470400                         LYCHEE HOUSE  MANHATTAN      141
# 24  50002265                       SUSHI NAKAZAWA  MANHATTAN       23
# 25  40942485                  107 WEST RESTAURANT  MANHATTAN     2787
# 26  41690780                       CAFE EVERGREEN  MANHATTAN     1367
# 27  50016219                     CRUMBS BAKE SHOP  MANHATTAN       40
# 80                       Japanese      10/08/2015
# 81                       American      05/27/2015
# 82                         Indian      08/05/2014
# 83                       Japanese      02/09/2015
# 84               CafÃ©/Coffee/Tea      04/13/2016
# 85                       American      12/09/2015
# 86                         Korean      05/08/2014
# 87                       American      09/09/2015
# 88                       American      05/10/2016
# 89                        Italian      04/08/2013
# 90                       Japanese      02/03/2015
# 91                       American      04/29/2016
# 92                        Italian      01/07/2015
# 93                       Japanese      12/10/2013
# 94                       American      04/11/2016
# 95                        Chinese      08/03/2015
# 96               CafÃ©/Coffee/Tea      05/01/2014
# 97                       American      06/27/2014
# 98                       American      01/21/2014
# 99                       American      01/07/2014
#
#                                              ACTION VIOLATION CODE  \
# 0   Violations were cited in the following area(s).            10F
# 1   Violations were cited in the following area(s).            06F
# 2   Violations were cited in the following area(s).            10F
# 3   Violations were cited in the following area(s).            06A
# 4   Violations were cited in the following area(s).            10H
# 5   Violations were cited in the following area(s).            06C
# 6   Violations were cited in the following area(s).            06D
# 7   Violations were cited in the following area(s).            06C
# 8   Violations were cited in the following area(s).            06C
# 9   Violations were cited in the following area(s).            10A
# 10  Violations were cited in the following area(s).            02G
# 11  Violations were cited in the following area(s).            04J
# 12  Violations were cited in the following area(s).            04N
# 13  Violations were cited in the following area(s).            02G
# 14  Violations were cited in the following area(s).            06C
# 15  Violations were cited in the following area(s).            02G
# 16  Violations were cited in the following area(s).            10F
# 17  Violations were cited in the following area(s).            10F
# 18  Violations were cited in the following area(s).            06E
# 19  Violations were cited in the following area(s).            08A
# 20  Violations were cited in the following area(s).            04H
# 21  Violations were cited in the following area(s).            08A
# 22  Violations were cited in the following area(s).            10F
# 23  Violations were cited in the following area(s).            08A
# 24  Violations were cited in the following area(s).            06D
# 25  Violations were cited in the following area(s).            02G
# 26  Violations were cited in the following area(s).            10H
# 27  Violations were cited in the following area(s).            06C
# 28  Violations were cited in the following area(s).            02G
# 29  Violations were cited in the following area(s).            04L
# ..                                              ...            ...
# 70  Violations were cited in the following area(s).            10F
# 71  Violations were cited in the following area(s).            06C
# 72  Violations were cited in the following area(s).            10C
# 73  Violations were cited in the following area(s).            06D
# 74  Violations were cited in the following area(s).            06D
# 75  Violations were cited in the following area(s).            08A
# 76  Violations were cited in the following area(s).            04B
# 77  Violations were cited in the following area(s).            10F
# 78  Violations were cited in the following area(s).            10F
# 79  Violations were cited in the following area(s).            10F
# 80  Violations were cited in the following area(s).            10F
# 81  Violations were cited in the following area(s).            10B
# 82  Violations were cited in the following area(s).            04A
# 83  Violations were cited in the following area(s).            10B
# 84  Violations were cited in the following area(s).            06D
# 85  Violations were cited in the following area(s).            10B
# 86  Violations were cited in the following area(s).            06C
# 87  Violations were cited in the following area(s).            04C
# 88  Violations were cited in the following area(s).            10F
# 89  Violations were cited in the following area(s).            10D
# 90  Violations were cited in the following area(s).            02B
# 91  Violations were cited in the following area(s).            08A
# 92  Violations were cited in the following area(s).            04N
# 93  Violations were cited in the following area(s).            06F
# 94  Violations were cited in the following area(s).            04N
# 95  Violations were cited in the following area(s).            02B
# 96  Violations were cited in the following area(s).            10F
# 97  Violations were cited in the following area(s).            06D
# 98  Violations were cited in the following area(s).            09B
# 99  Violations were cited in the following area(s).            04H
#
#                                 VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0   Non-food contact surface improperly constructe...  Not Critical   12.0
# 1   Wiping cloths soiled or not stored in sanitizi...      Critical   11.0
# 2   Non-food contact surface improperly constructe...  Not Critical    4.0
# 3   Personal cleanliness inadequate. Outer garment...      Critical   13.0
# 4   Proper sanitization not provided for utensil w...  Not Critical   36.0
# 5   Food not protected from potential source of co...      Critical   10.0
# 6   Food contact surface not properly washed, rins...      Critical    5.0
# 7   Food not protected from potential source of co...      Critical   20.0
# 8   Food not protected from potential source of co...      Critical   24.0
# 9   Toilet facility not maintained and provided wi...  Not Critical   11.0
# 10  Cold food item held above 41Âº F (smoked fish ...      Critical   11.0
# 11  Appropriately scaled metal stem-type thermomet...      Critical   22.0
# 12  Filth flies or food/refuse/sewage-associated (...      Critical   23.0
# 13  Cold food item held above 41Âº F (smoked fish ...      Critical   22.0
# 14  Food not protected from potential source of co...      Critical    7.0
# 15  Cold food item held above 41Âº F (smoked fish ...      Critical    7.0
# 16  Non-food contact surface improperly constructe...  Not Critical    5.0
# 17  Non-food contact surface improperly constructe...  Not Critical   11.0
# 18  Sanitized equipment or utensil, including in-u...      Critical    5.0
# 19  Facility not vermin proof. Harborage or condit...  Not Critical   23.0
# 20  Raw, cooked or prepared food is adulterated, c...      Critical   12.0
# 21  Facility not vermin proof. Harborage or condit...  Not Critical   19.0
# 22  Non-food contact surface improperly constructe...  Not Critical    7.0
# 23  Facility not vermin proof. Harborage or condit...  Not Critical   24.0
# 24  Food contact surface not properly washed, rins...      Critical   12.0
# 25  Cold food item held above 41Âº F (smoked fish ...      Critical   11.0
# 26  Proper sanitization not provided for utensil w...  Not Critical    5.0
# 27  Food not protected from potential source of co...      Critical   15.0
# 28  Cold food item held above 41Âº F (smoked fish ...      Critical   27.0
# 29  Evidence of mice or live mice present in facil...      Critical   11.0
# ..                                                ...           ...    ...
# 70  Non-food contact surface improperly constructe...  Not Critical   11.0
# 71  Food not protected from potential source of co...      Critical    7.0
# 72  Lighting inadequate; permanent lighting not pr...  Not Critical   12.0
# 73  Food contact surface not properly washed, rins...      Critical   12.0
# 74  Food contact surface not properly washed, rins...      Critical   10.0
# 75  Facility not vermin proof. Harborage or condit...  Not Critical   23.0
# 76  Food worker prepares food or handles utensil w...      Critical   12.0
# 77  Non-food contact surface improperly constructe...  Not Critical    3.0
# 78  Non-food contact surface improperly constructe...  Not Critical   10.0
# 79  Non-food contact surface improperly constructe...  Not Critical    9.0
# 80  Non-food contact surface improperly constructe...  Not Critical   10.0
# 81  Plumbing not properly installed or maintained;...  Not Critical   12.0
# 82  Food Protection Certificate not held by superv...      Critical   10.0
# 83  Plumbing not properly installed or maintained;...  Not Critical   12.0
# 84  Food contact surface not properly washed, rins...      Critical   10.0
# 85  Plumbing not properly installed or maintained;...  Not Critical   13.0
# 86  Food not protected from potential source of co...      Critical   11.0
# 23         141 EAST 55th STREET, 10022
# 24           23 COMMERCE STREET, 10014
# 25                2787 BROADWAY, 10025
# 26              1367 1st AVENUE, 10021
# 27                  40 BROAD ST, 10004
# 28               312 5th AVENUE, 10001
# 29        1619 AMSTERDAM AVENUE, 10031
# ..                                 ...
# 70          34 WEST 32nd STREET, 10001
# 71                23 CLINTON ST, 10002
# 72           511 W. 20TH STREET, 10011
# 73         210 WEST 10th STREET, 10014
# 74           1016 LEXINGTON AVE, 10021
# 75             393 LENOX AVENUE, 10027
# 76              2257 1st AVENUE, 10029
# 77           340 MADISON AVENUE, 10173
# 78                165 E 33RD ST, 10016
# 79           9 EAST 45th STREET, 10017
# 80         320 EAST 49th STREET, 10017
# 81               840 2nd AVENUE, 10017
# 82        1237 AMSTERDAM AVENUE, 10027
# 83              1280 1ST AVENUE, 10065
# 84                73 8th AVENUE, 10014
# 85       40012 WEST 54th STREET, 10019
# 86             28 W 33rd STREET, 10001
# 87              85 PEARL STREET, 10004
# 88               543 8th AVENUE, 10018
# 89          60 WEST 45th STREET, 10036
# 90           8 WEST 18th STREET, 10011
# 91       16 GRAMERCY PARK SOUTH, 10003
# 92    231 GRAND CENTRAL STATION, 10017
# 93                 24 PECK SLIP, 10038
# 94            158 LUDLOW STREET, 10002
# 95            137 EAST BROADWAY, 10002
# 96               362 2nd AVENUE, 10010
# 97              5 SPRING STREET, 10012
# 98               861 7th AVENUE, 10019
# 99       185 CHRISTOPHER STREET, 10014
#
# [100 rows x 19 columns]

# %% [markdown]
# ### Geocode Addresses

# %%
with open ('out.txt','w') as f: ##save addresses to txt file to batch geocode
 for i in range(len(samp)):
    f.write(samp['Address'][i]+ '\n')

# %%
adds = pd.read_csv("address.csv")
samp['lat']= adds['latitude']
samp['long']= adds['longitude']

# %%
# import time
# from rate_limited_queue import RateLimitedQueue, RateLimit
# from geopy.geocoders import Nominatim
# # import geopy
# geolocator = Nominatim()
# # location = geolocator.geocode("501 WEST 51st STREET, 10019")
# # print(location.address)
# mRests['lat']= 0.00
# mRests['long'] = 0.00

# samp = mRests.sample(90)
# samp=samp.reset_index(drop=True)

# addresses = samp['Address'].str.cat(sep='\n ')

# for j in range(0,2):
# #     print "this is j " + str(j)
#     for i in range(0+(45*j),45+(45*(j))):
# #     for i in range(len(samp)):
#         print i
#         #     address=' '.join(mRests['Address'][i].split())
#         address=samp['Address'][i]
#         #     print address

#         g = geolocator.geocode(mRests['Address'][i])
#         #     print g
#         lat = g.latitude
#         lon = g.longitude
#         samp.set_value(i,'lat',lat)
#         samp.set_value(i,'long',lon)

#     time.sleep(60)

# %% [markdown]
# # Using Basemap

# %%
from mpl_toolkits.basemap import Basemap

# %%
map = Basemap(projection='merc',
    resolution = 'h', area_thresh = .01,
    lat_0=40.7831, lon_0= -73.9712,
    llcrnrlon=-74.03, llcrnrlat=40.701,
    urcrnrlon=-73.86, urcrnrlat=40.901)
 
#     40.7831, -73.9712
    
map.drawcoastlines()
map.drawcountries()
map.drawstates()
map.drawrivers()
map.fillcontinents(color = 'gainsboro')
map.drawmapboundary(fill_color='steelblue')
map.plot(samp['lat'][1],samp['long'][1],'bo', markersize = 24)

# %% [markdown]
# # Using Folium

# %%
import folium

m = folium.Map(location=[40.7831, -73.9712], zoom_start =12)
marker_cluster = folium.MarkerCluster().add_to(m)
for i in range(len(samp)):
    if samp["GRADE"][i] =="A":
        folium.Marker([samp['lat'][i],samp['long'][i]], popup= "Name: " + str(samp['DBA'][i])+ '\n' + "Score: " + str(samp["SCORE"][i]) + '\n'+'Grade: '+ str(samp["GRADE"][i]),
                      icon=folium.Icon(color="green", icon='no-sign')).add_to(marker_cluster)
    elif samp["GRADE"][i]=="B":
         folium.Marker([samp['lat'][i],samp['long'][i]], popup= "Name: " + str(samp['DBA'][i])+ '\n' + "Score: " + str(samp["SCORE"][i]) + '\n'+'Grade: '+ str(samp["GRADE"][i]),
                      icon=folium.Icon(color='blue',icon='no-sign')).add_to(marker_cluster)
    else:
         folium.Marker([samp['lat'][i],samp['long'][i]], popup= "Name: " + str(samp['DBA'][i])+ '\n' + "Score: " + str(samp["SCORE"][i]) + '\n'+'Grade: '+ str(samp["GRADE"][i]),
                      icon=folium.Icon(color='red',icon='no-sign')).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
m.save('restaurants.html')

# %% [markdown]
# # Using Bokeh

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0d1fc3be-2301-4ae8-a159-6857dbcafd8b">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Histogram, output_file, show

# create a new plot with a title and axis labels
p1=Histogram(samp['SCORE'])
# output_file("histogram.html")

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="af54a737-eb69-44aa-8ed2-a288a72bdb91"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("af54a737-eb69-44aa-8ed2-a288a72bdb91");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'af54a737-eb69-44aa-8ed2-a288a72bdb91' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2183590b-b9d3-4209-bbcf-9d44b6dad606":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"292bf5bf-147f-40c4-a1a6-4aff5b022438","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(28.4, 30.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(28.4, 30.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1818181818181834],"x":["29.45"],"y":[0.0]}},"id":"8bb269bf-e04d-457c-975d-297880d78ea4","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"10178c70-c0ec-436f-a726-e8d00559bef4","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(24.0, 26.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(24.0, 26.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.18181818181818],"x":["25.1"],"y":[1.5]}},"id":"c3912f43-558e-4b66-bc21-ef3e2e258a03","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(15.3, 17.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(15.3, 17.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1818181818181817],"x":["16.4"],"y":[1.0]}},"id":"0a721ad1-90f0-4d9d-9eec-94eac81ab0fa","type":"ColumnDataSource"},{"attributes":{"location":"top_left","plot":{"id":"20520bdb-f0a8-4274-9093-4ead4838163e","subtype":"Chart","type":"Plot"}},"id":"65ca4259-3df7-4cfc-9409-6e3dd4c67d08","type":"Legend"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(13.1, 15.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(13.1, 15.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.1818181818181817],"x":["14.2"],"y":[1.5]}},"id":"167e0e5d-2233-468e-89a9-149923c2b240","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(45.8, 48.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(45.8, 48.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.181818181818187],"x":["46.9"],"y":[0.5]}},"id":"c6336281-b0ad-45f7-ba7a-d1ccba1cb84a","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":null},"id":"85f9d645-4ad0-4bc6-954f-c5781fcf258b","type":"Title"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7aa11c4b-9cdd-4a0c-a9de-e47dab2ec163","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"600aa7af-0141-4f38-8565-7927b9e210ef","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(43.6, 45.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(43.6, 45.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.18181818181818],"x":["44.7"],"y":[0.0]}},"id":"1e8bf91e-3759-4cf3-a68f ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[67]</strong>&gt;</code></p>

# %%
from bokeh.charts import Histogram, output_file, show
from bokeh.sampledata.autompg import autompg as df

p2 = Histogram(mRests,'SCORE', color='GRADE',
              title="Score Grouped by Grade", bins = 15,
              legend='top_right')

# output_file("histogram_color.html")

show(p2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3c71a35b-5496-4ef4-9cf5-9186865a6e3e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3c71a35b-5496-4ef4-9cf5-9186865a6e3e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3c71a35b-5496-4ef4-9cf5-9186865a6e3e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2f37a17a-d7a4-4c75-8df1-de9ef1e618ba":{"roots":{"references":[{"attributes":{"data_source":{"id":"b6fc59ca-d62d-4592-aada-bcba99297c55","type":"ColumnDataSource"},"glyph":{"id":"ae338252-81b7-4232-8592-4cbac37f4dc6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f2971242-1631-4340-9b75-22812379eff6","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"da17c50a-9dd7-4f83-813b-1dcecb61d58e","type":"ColumnDataSource"},"glyph":{"id":"2d3ba1e6-bcc6-4767-b7c9-e24896639085","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"04e06b22-918c-4939-8dce-76dbcee01b8c","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f81e5655-9a5d-4d40-97f4-9c2750633cc9","type":"ColumnDataSource"},"glyph":{"id":"eb043383-01b2-4eb2-99c9-b20789d5f20f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"01a762cf-3d6c-4f17-9965-9586881ee1f2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(40.0, 45.0]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[94.0],"label":["(40.0, 45.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.0],"x":["42.5"],"y":[47.0]}},"id":"c9bd3b5d-359b-4938-b0d7-874aad9ae2cf","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7e55956c-cb8e-49e4-bffb-52e8864b1a49","type":"ColumnDataSource"},"glyph":{"id":"e0509b6c-6cf0-4f6c-a7b1-38034a9caaa9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bce41dcd-e49f-4a11-afc3-191a2aba8cf2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc642e52-7931-468a-9b46-b6de45e542f9","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(12.0, 13.3]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[21.0],"label":["(12.0, 13.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3333333333333321],"x":["12.65"],"y":[10.5]}},"id":"49e0910f-133f-4be1-ae4c-06141864fe6a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"753e8c35-20e3-4926-a220-6bfc9b339635","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(43.7, 52.4]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[555.0],"label":["(43.7, 52.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[8.733333333333327],"x":["48.05"],"y":[277.5]}},"id":"f5787b34-f964-420f-aaa4-568a1683dfc9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f5a2a365-fbd2-4d44-b6d2-2839b480e490","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8d5a1a2-532f-48be-bcdc-343db0e40776","type":"Rect"},{"attributes":{"plot":{"id":"13dbb3d8-82f2-4001-867c-43b0e0af1b02","subtype":"Chart","type":"Plot"}},"id":"4c57eec3-5d5b-4b6e-b64e-2ae24241034b","type":"ResetTool"},{"attributes":{"data_source":{"id":"19c8d648-dddf-48b4-ada0-44fcc4971935","type":"ColumnDataSo ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[70]</strong>&gt;</code></p>

# %%
from bokeh.models.widgets import Panel, Tabs
from bokeh.io import output_file, show
from bokeh.plotting import figure

tab1 = Panel(child=p1, title="Frequency of Score")
tab2 = Panel(child=p2, title="By Grade")

tabs = Tabs(tabs=[ tab1, tab2 ])
output_file("tabs.html")

show(tabs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6397a84d-0103-4147-8e72-7f3e10937158"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6397a84d-0103-4147-8e72-7f3e10937158");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6397a84d-0103-4147-8e72-7f3e10937158' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"862e72f0-8e5a-428c-841c-6ac94e36daac":{"roots":{"references":[{"attributes":{"data_source":{"id":"b6fc59ca-d62d-4592-aada-bcba99297c55","type":"ColumnDataSource"},"glyph":{"id":"ae338252-81b7-4232-8592-4cbac37f4dc6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f2971242-1631-4340-9b75-22812379eff6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a0fae786-b962-4848-9f64-6eecd7c6a89f","type":"Rect"},{"attributes":{"data_source":{"id":"f81e5655-9a5d-4d40-97f4-9c2750633cc9","type":"ColumnDataSource"},"glyph":{"id":"eb043383-01b2-4eb2-99c9-b20789d5f20f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"01a762cf-3d6c-4f17-9965-9586881ee1f2","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7e55956c-cb8e-49e4-bffb-52e8864b1a49","type":"ColumnDataSource"},"glyph":{"id":"e0509b6c-6cf0-4f6c-a7b1-38034a9caaa9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bce41dcd-e49f-4a11-afc3-191a2aba8cf2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d3bdacba-b9e2-4ed8-b2d8-f2adc0e7bad3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc642e52-7931-468a-9b46-b6de45e542f9","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(12.0, 13.3]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[21.0],"label":["(12.0, 13.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.3333333333333321],"x":["12.65"],"y":[10.5]}},"id":"49e0910f-133f-4be1-ae4c-06141864fe6a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"292bf5bf-147f-40c4-a1a6-4aff5b022438","type":"Rect"},{"attributes":{"data_source":{"id":"a88509c8-fed6-4364-a78c-e93231914c71","type":"ColumnDataSource"},"glyph":{"id":"b904bc4f-e308-4b5f-b0c8-489a8161f739","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f9395b31-0c0d-4904-bc60-a63c27cddeb6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(43.7, 52.4]"],"color":["#407ee7"],"fill_alpha":[0.6],"height":[555.0],"label":["(43.7, 52.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[8.733333333333327],"x":["48.05"],"y":[277.5]}},"id":"f5787b34-f964-420f-aaa4-568a1683dfc9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f5a2a365-fbd2-4d44-b6d2-2839b480e490","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8d5a1a2-532f-48be-bcdc-343db0e40776","type":"Rect"},{"attributes":{"plot":{"id":"13dbb3d8-82f2-4001-867c-43b0e0af1b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[71]</strong>&gt;</code></p>

# %% [markdown]
# # Using Plotly

# %%
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
plotly.tools.set_credentials_file(username='hshapiro93', api_key='bol6m6pqqm')


x = mRests['GRADE']

tr1 = Histogram(x=x, histnorm='probability density', 
                xbins=dict(start=np.min(x), size= 0.25, end= np.max(x)),
                marker=dict(color='rgb(0,0,100)'))

title =" Probability Density of Grades"

layout = dict(
            title=title,
            autosize= True,
            bargap= 0.015,
            height= 600,
            width= 700,       
            hovermode= 'x',
            xaxis=dict(
            autorange= True,
            zeroline= False),
            yaxis= dict(
            autorange= True,
            showticklabels= True,
           ))
fig1 = Figure(data=Data([tr1]), layout=layout)
py.iplot(fig1)
# Out:
# c:\python27\lib\site-packages\plotly\plotly\plotly.py:236: UserWarning:
#
# Woah there! Look at all those points! Due to browser limitations, the Plotly SVG drawing functions have a hard time graphing more than 500k data points for line charts, or 40k points for other types of charts. Here are some suggestions:
# (1) Use the `plotly.graph_objs.Scattergl` trace object to generate a WebGl graph.
# (2) Trying using the image API to return an image instead of a graph URL
# (3) Use matplotlib
# (4) See if you can create your visualization with fewer data points
#
# If the visualization you're using aggregates points (e.g., box plot, histogram, etc.) you can disregard this warning.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hshapiro93/26.embed" height="600px" width="700px"></iframe>

# %%
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
plotly.tools.set_credentials_file(username='hshapiro93', api_key='bol6m6pqqm')


x = samp['SCORE']

tr1 = Histogram(x=x, histnorm='probability density', 
                xbins=dict(start=np.min(x), size= 0.25, end= np.max(x)),
                marker=dict(color='rgb(0,0,100)'))

title =" Probability Density of Scores"

layout = dict(
            title=title,
            autosize= True,
            bargap= 0.015,
            height= 600,
            width= 700,       
            hovermode= 'x',
            xaxis=dict(
            autorange= True,
            zeroline= False),
            yaxis= dict(
            autorange= True,
            showticklabels= True,
           ))
fig1 = Figure(data=Data([tr1]), layout=layout)
py.iplot(fig1)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hshapiro93/28.embed" height="600px" width="700px"></iframe>

# %%
trace = Histogram(x=mRests['SCORE'])

data = Data([trace])


fig = dict(data=data)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hshapiro93/30.embed" height="525px" width="100%"></iframe>

# %%
samp['text'] = "Name: " + samp['DBA'].astype(str)+ '\n' + "Score: " + samp["SCORE"].astype(str) + '\n'+'Grade: '+ samp["GRADE"].astype(str)

scl = [ [0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
    [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"] ]

data = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = samp['long'],
        lat = samp['lat'],
        text = samp['text'],
        mode = 'markers',
        marker = dict( 
            size = 8, 
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'square',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale = scl,
            cmin = 0,
            color = samp['SCORE'],
            cmax = samp['SCORE'].max(),
            colorbar=dict(
                title="Restaurant Score"
            )
        ))]

layout = dict(
        title = 'Restaurant Scores',
#         colorbar = True,   
        geo = dict(
            scope='usa',
#             projection=dict( type='albers usa' ),
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.5,
            subunitwidth = 0.5        
        ),
    )

fig = dict( data=data, layout=layout )
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~hshapiro93/32.embed" height="525px" width="100%"></iframe>
